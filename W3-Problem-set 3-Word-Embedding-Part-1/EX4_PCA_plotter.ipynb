# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
import matplotlib.pyplot as plt
import math

# %%
data_path = "result/TD.csv"
data = pd.read_csv(data_path, index_col=0)

# %%
data
# Out:
#         Rank Insignia of the Islamic Revolutionary Guard Corps  Botany  \
# 0                                                       0            0
# 000                                                     0            4
# 0001                                                    0            0
# 001                                                     0            0
# 006                                                     0            0
# ...                                                   ...          ...
# ḥanīfa                                                  0            1
# 啞陳                                                      0            0
# 文杜陵                                                     0            0
# 沙胡重                                                     0            0
# 麻裏蘆                                                     0            0
#
#         Russell's teapot  I Am the Resurrection (album)  Rolling hash  Brunei  \
# ...

# %%
X = StandardScaler().fit_transform(data.values).T

# %%
X.shape
# Out:
# (50, 13345)

# %%
sklearn_pca = PCA(n_components=2)
Y_sklearn = sklearn_pca.fit_transform(X)

sklearn_pca.explained_variance_ratio_
# Out:
# array([0.13720942, 0.06751938])

# %%
sklearn_pca.explained_variance_ratio_.sum()
# Out:
# 0.20472879478469208

# %%
sklearn_pca.components_
# Out:
# array([[ 0.00145423,  0.00146111,  0.00019355, ..., -0.00028568,
#         -0.00028568, -0.00028568],
#        [-0.00543118,  0.00034027,  0.00044265, ...,  0.00030148,
#          0.00030148,  0.00030148]])

# %%
Y_sklearn.shape
# Out:
# (50, 2)

# %%
label = data.columns.to_list()
label = list(map(lambda x: " ".join(x.split()[:2]) + "...", label))
label
# Out:
# ['Rank Insignia...',
#  'Botany...',
#  "Russell's teapot...",
#  'I Am...',
#  'Rolling hash...',
#  'Brunei...',
#  'The Patriotic...',
#  'Nick Gillingham...',
#  'Herbert M....',
#  'Gordon Durie...',
#  'I Vampiri...',
#  'Rail transport...',
#  'WWF WrestleMania...',
#  'Jun of...',
#  'HNoMS Ørnen...',
#  'John Shoop...',
#  'Nuria Olivé...',
#  'Emergence (Star...',
#  'There Are...',
#  'Lake Mountain...',
#  'Variable darner...',
#  'Patricia Davidson...',
#  'Alison Newman...',
#  'Binary function...',
#  'Arthur W....',
#  'H.E.A.R....',
#  'Claude Alvares...',
#  'Embrace (novel)...',
#  'Reed frog...',
#  'Alfonso III...',
#  'List of...',
#  'Brit milah...',
#  'Adrian Lamo...',
#  'Aomori Curling...',
#  'Rotary vane...',
#  'Red Water...',
#  'Lory (disambiguation)...',
#  'Ernest C....',
#  'Avionics...',
#  'Hindi cinema...',
#  'Mike Junkin...',
#  'Court of...',
#  'Isiro...',
#  'Bishop...',
#  "Now That's...",
#  'Tourism in...',
# ...

# %%
plt.figure(figsize=(15, 15))

for text, x, y in zip(label, Y_sklearn[:, 0], Y_sklearn[:, 1]):
    plt.annotate(
        text,
        xy=(x, y), xytext=(math.copysign(40, x), math.copysign(20, y)),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'),
        fontsize=8
    )
    plt.arrow(0, 0, x, y, head_width=0.5, head_length=0.5, fc='k', ec='k')
plt.grid()
plt.title(f"PCA with 2 components - {sklearn_pca.explained_variance_ratio_.sum() * 100:.2f}% variance explained", fontsize=20)
plt.show()
